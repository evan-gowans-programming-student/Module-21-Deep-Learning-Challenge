# %%
# Import Dependencies
import tensorflow as tf
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# Load Dataset
url = "https://static.bc-edx.com/data/dl-1-2/m21/lms/starter/charity_data.csv"
application_df = pd.read_csv(url)

# Display first few rows
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop ID Columns (not useful for prediction)
application_df = application_df.drop(columns=["EIN", "NAME"])

# Check Unique Values to Identify Categorical Variables
application_df.nunique()
# Out:
# APPLICATION_TYPE            17
# AFFILIATION                  6
# CLASSIFICATION              71
# USE_CASE                     5
# ORGANIZATION                 4
# STATUS                       2
# INCOME_AMT                   9
# SPECIAL_CONSIDERATIONS       2
# ASK_AMT                   8747
# IS_SUCCESSFUL                2
# dtype: int64

# %%
# Group Rare APPLICATION_TYPE Categories
application_counts = application_df['APPLICATION_TYPE'].value_counts()
application_types_to_replace = application_counts[application_counts < 500].index.tolist()
for app in application_types_to_replace:
    application_df['APPLICATION_TYPE'] = application_df['APPLICATION_TYPE'].replace(app, "Other")

# Group Rare CLASSIFICATION Categories
classification_counts = application_df['CLASSIFICATION'].value_counts()
classifications_to_replace = classification_counts[classification_counts < 100].index.tolist()
for cls in classifications_to_replace:
    application_df['CLASSIFICATION'] = application_df['CLASSIFICATION'].replace(cls, "Other")

# Apply One-Hot Encoding to Categorical Columns
application_df = pd.get_dummies(application_df, columns=["APPLICATION_TYPE", "CLASSIFICATION", "AFFILIATION", "USE_CASE", "ORGANIZATION", "INCOME_AMT", "SPECIAL_CONSIDERATIONS"], drop_first=True)

# Display Data Types to Confirm Encoding
application_df.dtypes
# Out:
# STATUS                       int64
# ASK_AMT                      int64
# IS_SUCCESSFUL                int64
# APPLICATION_TYPE_T10          bool
# APPLICATION_TYPE_T19          bool
# APPLICATION_TYPE_T3           bool
# APPLICATION_TYPE_T4           bool
# APPLICATION_TYPE_T5           bool
# APPLICATION_TYPE_T6           bool
# APPLICATION_TYPE_T7           bool
# APPLICATION_TYPE_T8           bool
# CLASSIFICATION_C1200          bool
# CLASSIFICATION_C1270          bool
# CLASSIFICATION_C1700          bool
# CLASSIFICATION_C2000          bool
# CLASSIFICATION_C2100          bool
# CLASSIFICATION_C2700          bool
# CLASSIFICATION_C3000          bool
# CLASSIFICATION_C4000          bool
# CLASSIFICATION_C5000          bool
# CLASSIFICATION_C7000          bool
# CLASSIFICATION_Other          bool
# AFFILIATION_Family/Parent     bool
# AFFILIATION_Independent       bool
# AFFILIATION_National          bool
# AFFILIATION_Other             bool
# AFFILIATION_Regional          bool
# USE_CASE_Heathcare            bool
# USE_CASE_Other                bool
# USE_CASE_Preservation         bool
# USE_CASE_ProductDev           bool
# ORGANIZATION_Co-operative     bool
# ORGANIZATION_Corporation      bool
# ORGANIZATION_Trust            bool
# INCOME_AMT_1-9999             bool
# INCOME_AMT_10000-24999        bool
# INCOME_AMT_100000-499999      bool
# INCOME_AMT_10M-50M            bool
# INCOME_AMT_1M-5M              bool
# INCOME_AMT_25000-99999        bool
# INCOME_AMT_50M+               bool
# INCOME_AMT_5M-10M             bool
# SPECIAL_CONSIDERATIONS_Y      bool
# dtype: object

# %%
# Define Features (X) and Target (y)
y = application_df["IS_SUCCESSFUL"].values
X = application_df.drop(columns=["IS_SUCCESSFUL"])

# Split Data into Training and Testing Sets
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=78)

# Confirm Shapes of Training and Testing Sets
print(f"Training Features Shape: {X_train.shape}")
print(f"Testing Features Shape: {X_test.shape}")
# Out:
# Training Features Shape: (25724, 42)
# Testing Features Shape: (8575, 42)

# %%
# Apply StandardScaler to Normalize Feature Data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# Confirm Scaling by Printing First Few Rows
print(X_train_scaled[:5])
# Out:
# [[ 1.39430557e-02 -3.34843874e-02 -1.26474869e-01 -1.80310401e-01
#   -1.93323172e+00 -2.17211760e-01 -1.88868073e-01  5.27316518e+00
#   -1.44900757e-01 -1.47122472e-01 -4.05336896e-01 -5.47932520e-02
#   -9.28767886e-02  2.15062580e+00 -2.41986076e-01 -5.29792289e-02
#   -2.43601984e-01 -7.58112863e-02 -6.05605239e-02 -1.51342016e-01
#   -1.39638995e-01 -4.50061455e-02 -1.07924659e+00 -3.18080475e-02
#   -6.23503924e-03 -1.97203755e-02 -6.21563724e-02 -8.81784846e-03
#   -2.13840836e+00  2.25801349e+00 -1.17446358e-01 -3.35950033e-02
#   -1.39638995e-01 -4.50061455e-02  9.26572303e-01 -3.18080475e-02
#   -6.23503924e-03 -1.97203755e-02 -6.21563724e-02 -8.81784846e-03
#    4.67637529e-01 -4.42867150e-01 -1.17446358e-01 -3.35950033e-02
#    6.75069188e-01 -1.48495575e-01 -1.26949951e-01 -3.29185563e-01
#    1.19798520e+01 -1.69813249e-01 -3.51865775e-01 -6.40196894e-02
#   -6.98784891e-02 -2.78942470e-02]]

# %%
# Define Neural Network Model
nn = tf.keras.models.Sequential()

# First Hidden Layer - Increased neurons & LeakyReLU activation
nn.add(tf.keras.layers.Dense(units=100, activation=tf.keras.layers.LeakyReLU(alpha=0.01), input_dim=X_train_scaled.shape[1]))

# Second Hidden Layer - More neurons & activation change
nn.add(tf.keras.layers.Dense(units=50, activation='tanh'))

# Third Hidden Layer - Added new layer
nn.add(tf.keras.layers.Dense(units=25, activation='relu'))

# Dropout Layer to prevent overfitting
nn.add(tf.keras.layers.Dropout(0.5))

# Output Layer - Sigmoid for binary classification
nn.add(tf.keras.layers.Dense(units=1, activation='sigmoid'))

# Display Model Summary
nn.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_8 (Dense)                 │ (None, 100)            │         4,300 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_9 (Dense)                 │ (None, 50)             │         5,050 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_10 (Dense)                │ (None, 25)             │         1,275 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 25)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_11 (Dense)                │ (None, 1)              │            26 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 10,651 (41.61 KB)
#  Trainable params: 10,651 (41.61 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Compile Model with Optimized Parameters
nn.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# Implement Early Stopping to Prevent Overtraining
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=10)

# Train Model with Increased Epochs
fit_model = nn.fit(X_train_scaled, y_train, epochs=40, batch_size=64, callbacks=[early_stopping])
# Out:
# Epoch 1/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.6840 - loss: 0.6139
# Epoch 2/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7263 - loss: 0.5735
# Epoch 3/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7273 - loss: 0.5690
# Epoch 4/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.7341 - loss: 0.5564
# Epoch 5/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7261 - loss: 0.5611
# Epoch 6/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7311 - loss: 0.5592
# Epoch 7/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7333 - loss: 0.5573
# Epoch 8/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7291 - loss: 0.5562
# Epoch 9/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7340 - loss: 0.5557
# Epoch 10/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7274 - loss: 0.5628
# Epoch 11/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7297 - loss: 0.5570
# Epoch 12/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7280 - loss: 0.5600
# Epoch 13/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7269 - loss: 0.5555
# Epoch 14/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7299 - loss: 0.5543
# Epoch 15/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7322 - loss: 0.5516
# Epoch 16/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7327 - loss: 0.5544
# Epoch 17/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7289 - loss: 0.5547
# Epoch 18/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7361 - loss: 0.5492
# Epoch 19/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7395 - loss: 0.5465
# Epoch 20/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7322 - loss: 0.5520
# Epoch 21/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7333 - loss: 0.5527
# Epoch 22/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7327 - loss: 0.5539
# Epoch 23/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7333 - loss: 0.5535
# Epoch 24/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7323 - loss: 0.5514
# Epoch 25/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7346 - loss: 0.5527
# Epoch 26/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7374 - loss: 0.5506
# Epoch 27/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7343 - loss: 0.5528
# Epoch 28/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7331 - loss: 0.5548
# Epoch 29/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7354 - loss: 0.5460
# Epoch 30/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7390 - loss: 0.5438
# Epoch 31/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.7336 - loss: 0.5492
# Epoch 32/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7376 - loss: 0.5502
# Epoch 33/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7407 - loss: 0.5455
# Epoch 34/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7363 - loss: 0.5496
# Epoch 35/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7360 - loss: 0.5488
# Epoch 36/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7320 - loss: 0.5493
# Epoch 37/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7339 - loss: 0.5535
# Epoch 38/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7354 - loss: 0.5516
# Epoch 39/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.7344 - loss: 0.5463
# Epoch 40/40
# 402/402 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.7349 - loss: 0.5463

# %%
# Evaluate Model Performance
model_loss, model_accuracy = nn.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Optimized Loss: {model_loss}, Optimized Accuracy: {model_accuracy}")
# Out:
# 268/268 - 1s - 3ms/step - accuracy: 0.7269 - loss: 0.5518
# Optimized Loss: 0.5517569184303284, Optimized Accuracy: 0.7268804907798767

# %%
# Save the Optimized Model to an HDF5 File
nn.save("AlphabetSoupCharity_Optimization.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
